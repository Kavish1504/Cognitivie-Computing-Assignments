# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavish1504/Cognitivie-Computing-Assignments/blob/main/Cognitive_Computing_Assignment_11(102317012).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name - Kavish Gupta
#
# Subgroup- 2Q11
#
# Roll No.-102317012
#
# Assignment-11

# %% [markdown]
# ![Screenshot 2025-05-07 160305.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-05-07 160451.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-05-07 160612.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-05-07 160648.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-05-07 160916.png](data:image/png;base64,...)
