# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavish1504/Cognitivie-Computing-Assignments/blob/main/Cognitive_Computing_Assignment_5(102317012).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name-Kavish Gupta**
#
# **Roll No.-102317012**
#
# **Subgroup-2Q11**
#
# **Assignment-5**

# %% [markdown]
# Q1. For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
#
# i. Sum of all elements
#
# ii. Sum of all elements row-wise
#
# iii. Sum of all elements column-wise

# %%
import numpy as np
gfg = np.matrix('[4,1,9;12,3,1;4,5,6]')
total_sum = 0
rows, cols = gfg.shape

for i in range(rows):
    for j in range(cols):
        total_sum += gfg[i, j]

print(total_sum)
# Out:
# 45

# %%
import numpy as np
gfg = np.matrix('[4,1,9;12,3,1;4,5,6]')
total_sum = 0
rows, cols = gfg.shape

for i in range(rows):
    total_sum=0
    for j in range(cols):
        total_sum += gfg[i, j]
    print(total_sum)
# Out:
# 14
# 16
# 15

# %%
import numpy as np
gfg = np.matrix('[4,1,9;12,3,1;4,5,6]')
total_sum = 0
rows, cols = gfg.shape

for i in range(rows):
    total_sum=0
    for j in range(cols):
        total_sum += gfg[j, i]
    print(total_sum)
# Out:
# 20
# 9
# 16

# %% [markdown]
# Q2. (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
#
# i. Sorted array
#
# ii. Indices of sorted array
#
# iii. 4 smallest elements
#
# iv. 5 largest elements
#  (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
#
# i. Integer elements only
#
# ii. Float elements only

# %%
import numpy as np
array=np.array([10,52,62,16,16,54,453])
sorted=np.sort(array)
print(sorted)
print()
l=list(array)
for i in sorted:
    if(i in l):
        print(l.index(i),end=' ')
print()
for i in range(0,5):
    if(sorted[i]==sorted[i+1]):
        continue
    print(sorted[i])

n=len(sorted)
print()
for i in range(1, 7):
    if n - i - 1 >= 0 and sorted[n - i] == sorted[n - i - 1]:
        continue
    print(sorted[n - i])
# Out:
# [ 10  16  16  52  54  62 453]
#
# 0 3 3 1 5 2 6
# 10
# 16
# 52
# 54
#
# 453
# 62
# 54
# 52
# 16

# %%
import numpy as np
array=np.array([1.0,1.2,2.2,2.0,3.0,2.0])
for i in array:
    if(i==int(i)):
        print(i)
print()
for i in array:
    if(i==float(i)):
        print(i)
# Out:
# 1.0
# 2.0
# 3.0
# 2.0
#
# 1.0
# 1.2
# 2.2
# 2.0
# 3.0
# 2.0

# %% [markdown]
# 3. You are given a weekly sales dataset and need to perform various operations
# using NumPy broadcasting.
#
# a) Generate your unique sales dataset:
#  Take the sum of the ASCII values of the initials of your first and last
# name. Call this value X. (If your initials are A B → ASCII sum = 65
# + 66 = 131 → sales = [131, 181, 231, 281, 331].)
#  Create a NumPy array sales with values [X, X+50, X+100, X+150,
# X+200].
#
# b) Compute your personalized tax rate as ((X % 5) + 5) / 100.
#
#  Use broadcasting to apply this tax rate to each sales value.
#
# c) Adjust sales based on discount:
#
#  If sales < X+100, apply a 5% discount.
#
#  If sales >= X+100, apply a 10% discount.
#
# d) Expand sales data for multiple weeks:
#
#  Create a 3×5 matrix representing three weeks of sales by stacking
# sales three times using broadcasting.
#
#  Increase sales by 2% per week using element-wise broadcasting.

# %%
import numpy as np
ascii=ord('K')
print(ascii)
ascii2=ord('G')
asciii=ascii+ascii2
dataset=[]
dataset.append(asciii)
for i in range(1,5):
    dataset.append(asciii+50*i)
dataset=np.array(dataset)
print(dataset)

#b
tax=((asciii%5)+5)/100
print(tax)

tax_array=dataset*tax
print(tax_array)

#c
sales=asciii+100
discount=[]
for i in dataset:
    if(i<sales):
        discount.append(i-i*0.05)
    elif(i>=sales):
        discount.append(i-i*0.1)
print(discount)

sales_week=np.array([100,200,300,400,500,200,400,600,800,1000,400,800,1200,1600,2000])
sales_week = sales_week.reshape(3, 5)
print("the sales of the 3 weeks are :")
print(sales_week)
week_inc= np.array([1.02,1.04,1.06]).reshape(3,1)
updated=sales_week*week_inc
print("the updated sales are : ")
print(updated)
# Out:
# 75
# [146 196 246 296 346]
# 0.06
# [ 8.76 11.76 14.76 17.76 20.76]
# [138.7, 186.2, 221.4, 266.4, 311.4]
# the sales of the 3 weeks are :
# [[ 100  200  300  400  500]
#  [ 200  400  600  800 1000]
#  [ 400  800 1200 1600 2000]]
# the updated sales are :
# [[ 102.  204.  306.  408.  510.]
#  [ 208.  416.  624.  832. 1040.]
#  [ 424.  848. 1272. 1696. 2120.]]

# %% [markdown]
# 4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use
# each function from the list below and compute y values using NumPy:
#
#  Y = x^2
#
#  Y = sin(x)
#
#  Y = e^x
#
#  Y = log(|x| + 1)
#
# Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-10, 10, 100)
y = x**2
plt.plot(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-10, 10, 100)
y = np.sin(x)
plt.plot(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-10, 10, 100)
y = np.e**x
plt.plot(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-10, 10, 100)
y = np.log(np.abs(x))+1
plt.plot(x, y)
